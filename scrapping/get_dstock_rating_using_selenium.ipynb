# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from bs4 import BeautifulSoup
import pandas as pd

# %%
market_data = pd.read_csv(
    'https://raw.githubusercontent.com/thinh-vu/vnstock/beta/data/listing_companies_enhanced-2023.csv')
tickers = market_data['ticker'].to_list()

# %%
# Initialize the WebDriver
service = Service(executable_path=r'C:\Users\Dell\Downloads\App\chromedriver_win32_v1\chromedriver.exe')
driver = webdriver.Chrome(service=service)

dstock_rating = {}

# Get the page HTML source
for ticker in tickers:
    try:
        url = f'https://dstock.vndirect.com.vn/tong-quan/{ticker}'
        driver.get(url)
        driver.implicitly_wait(5)  # Wait for the page to load
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        dstock_rating[ticker] = soup.find('div', class_="box-index__rate").get_text()
        print(f'{ticker}: {dstock_rating[ticker]}')
    except Exception as e:
        print(e)

# Close the WebDriver
driver.quit()
# Out:
# VVS: 4.05/10
# XDC: 0/10
# HSV: 2.4/10
# CST: 4.25/10
# BVL: 3.35/10
# SGI: 3.35/10
# TOS: 4.25/10
# VTZ: 3.45/10
# SSH: 4.95/10
# BCA: 3.7/10
# FUCTVGF3: 0/10
# FUEIP100: 0/10
# GMH: 4.6/10
# BIG: 1.6/10
# CMM: 3/10
# CNA: 0/10
# FUEKIV30: 0/10
# ODE: 0/10
# HMR: 3.4/10
# PCH: 3.7/10
# DSD: 4.05/10
# NO1: 3.8/10
# MGR: 2.55/10
# PPT: 3.45/10
# CAR: 0/10
# GPC: 2.4/10
# FUCTVGF4: 0/10
# FUEDCMID: 0/10
# FUEKIVFS: 0/10
# FUEMAVND: 0/10
# FUEFCV50: 0/10
# GCF: 2.25/10
# LPT: 2.55/10
# AAA: 5.05/10
# AAM: 2.7/10
# AAT: 1.45/10
# AAV: 3/10
# ABB: 1.45/10
# 'NoneType' object has no attribute 'get_text'
# ABR: 5.15/10
# ABS: 2.3/10
# ABW: 2/10
# ABT: 5/10
# ACB: 7.6/10
# ACC: 4.15/10
# ACE: 4.15/10
# ACL: 2.8/10
# ACM: 1.75/10
# ACS: 2.15/10
# ACV: 5.95/10
# ADC: 6.2/10
# ADP: 4.85/10
# AFX: 1.85/10
# AGF: 2.35/10
# CKA: 5.3/10
# AGP: 4/10
# AGM: 1.2/10
# CAG: 3.1/10
# LTG: 4.85/10
# AGR: 4.7/10
# AGG: 0/10
# 'NoneType' object has no attribute 'get_text'
# ...

# %%
dstock_rating
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dstock_rating
#
# NameError: name 'dstock_rating' is not defined
